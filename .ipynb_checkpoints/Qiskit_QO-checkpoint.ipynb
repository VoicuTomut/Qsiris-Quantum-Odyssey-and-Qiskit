# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.compiler import transpile


import numpy as np 

from conversion_qiskit_qo import circuit_to_puzzle,seve_puzzle

# %% [markdown]
# ## Examples :

# %% [markdown]
# ### Example_001:
#
# If all the the gates are supported in QO the circuit can be converted directly from qiskit to QO format.

# %%
qreg_q=QuantumRegister(3,'q')
circuit = QuantumCircuit(qreg_q)

circuit.cx(qreg_q[1],qreg_q[2])


circuit.h(qreg_q[1])
circuit.z(qreg_q[2])
circuit.u3(np.pi/7,np.pi/3,np.pi/5,qreg_q[0])


circuit.draw('mpl')
# Out:
# <ipython-input-2-4372eb1ea6ab>:9: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   circuit.u3(np.pi/7,np.pi/3,np.pi/5,qreg_q[0])

# %%
puzzle=circuit_to_puzzle(circuit)
seve_puzzle(puzzle, 'example_001' )
# Out:
# circuit-0 saved:Circuits/QK_QO/example_001.qpf

# %% [markdown]
# ### Example_002
#
# If you have more complex gates it would be better if you transpile your circuit first at least for the moment.

# %%
qreg_q=QuantumRegister(4,'q')
circuit = QuantumCircuit(qreg_q)

circuit.cx(qreg_q[1],qreg_q[2])


circuit.h(qreg_q[1])
circuit.z(qreg_q[3])
circuit.u3(np.pi/7,np.pi/3,np.pi/5,qreg_q[0])
circuit.swap(qreg_q[0], qreg_q[3])

circuit.draw('mpl')

# %%
circuit = transpile(circuit, basis_gates=['id','u3', 'cx'], optimization_level=1, seed_transpiler=1) 
circuit.draw(output='mpl')

# %%
puzzle=circuit_to_puzzle(circuit)
seve_puzzle(puzzle, 'example_002' )
# Out:
# circuit-1 saved:Circuits/QK_QO/example_002.qpf

# %% [markdown]
# ### Example_003

# %%
circuit = QuantumCircuit(2,name='matchgate_2Q')

circuit.cx(0,1)
circuit.z(0)
circuit.cry(np.pi/7,1,0)
circuit.cx(0,1)

circuit.draw('mpl')

# %%
circuit = transpile(circuit, basis_gates=['id','u3', 'cx'], optimization_level=1, seed_transpiler=1) 
circuit.draw(output='mpl')

# %%
puzzle=circuit_to_puzzle(circuit)
seve_puzzle(puzzle, 'example_003' )
# Out:
# matchgate_2Q saved:Circuits/QK_QO/example_003.qpf
